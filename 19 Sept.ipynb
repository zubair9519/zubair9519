# %%
import requests
import pandas as pd
# Your read-only token (starts with 'api:')
api_token = '  '

# Organization ID (replace with your actual organization ID)
organization_id = '638ff0f4a2101f386901bf22'

# API endpoint to get circles in the organization
api_url = f'https://app.holaspirit.com/api/organizations/{organization_id}/circles?page=1&count=50'

# Headers for the GET request
headers = {
    'Authorization': f'Bearer {api_token}',
    'Accept': 'application/json'
}

# Send the GET request
response = requests.get(api_url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    print("Data successfully retrieved!")
    data = response.json()

    # Print the raw JSON response (optional, for inspection)
    # print(json.dumps(data, indent=4))

    # Let's extract relevant fields from the circles and store them in a DataFrame
    circles_data = []

    for circle in data['data']:
        circle_info = {
            'Circle ID': circle['id'],
            'Name': circle['name'],
            'Lead': circle['lead'],
            'Parent Circle': circle.get('parentCircle', 'N/A'),
            'Roles Count': circle['rolesCount'],
            'Members Count': circle['membersCount'],
            'Created At': circle['createdAt'],
            'Updated At': circle['updatedAt']
        }
        circles_data.append(circle_info)

    # Create a pandas DataFrame for better visualization
    df = pd.DataFrame(circles_data)

    # Display the DataFrame in a clean format
    from IPython.display import display
    display(df)

else:
    print(f"Failed to access the API. Status code: {response.status_code}")
    print("Error message:", response.text)
# Out:
# Data successfully retrieved!
#                    Circle ID                                         Name  \
# 0   638ff0f6a2101f386901c0ea                             Asset Management
# 1   638ff0f6a2101f386901bf4d                                    Batteries
# 2   66e020263cffacf97d09a48e              Battery Brunsbüttel Development
# 3   638ff0f6a2101f386901bf6f                          Battery Engineering
# 4   656f019a26b427d0770ee59c                                Battery@Solar
# 5   638ff0f6a2101f386901bfb3                          Business Excellence
# 6   656341d037d713f77b0ff843                          Contract Management
# 7   638ff0f6a2101f386901c154       Controlling & Financial Administration
# 8   638ff0f6a2101f386901c014                                     Delivery
# 9   638ff0f6a2101f386901c034                        Delivery Construction
# 10  659e5cc6c375d6022b0582dd                   Digital project management
# ...

# %%
import requests

# Your organization ID and API token


# API endpoint to get circles in the organization
api_url = f'https://app.holaspirit.com/api/organizations/{organization_id}/circles?page=1&count=30'

# Headers for the GET request
headers = {
    'Authorization': f'Bearer {api_token}',
    'Accept': 'application/json'
}

# Send the GET request
response = requests.get(api_url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    print("Data successfully retrieved!")
    data = response.json()

    # Create a list to store the parent and sub-circles
    parent_and_sub_circles = []

    # Loop through the circles data to extract parentCircle and subRoles
    for circle in data['data']:
        parent_circle = circle.get('parentCircle', 'None')
        sub_circles = circle.get('subRoles', [])

        # Append the parent circle and sub-circle information
        parent_and_sub_circles.append({
            'Parent Circle': parent_circle,
            'Sub Circles': sub_circles
        })

    # Display the list of parent circles and their sub-circles
    for entry in parent_and_sub_circles:
        print(f"Parent Circle ID: {entry['Parent Circle']}")
        print(f"Sub Circles: {entry['Sub Circles']}")
        print("-" * 40)

else:
    print(f"Failed to access the API. Status code: {response.status_code}")
    print("Error message:", response.text)
# Out:
# Data successfully retrieved!
# Parent Circle ID: 638ff0f6a2101f386901c014
# Sub Circles: ['638ff0f7a2101f386901c3f8', '638ff0f7a2101f386901c3ff', '638ff0f7a2101f386901c406', '638ff0f7a2101f386901c416', '638ff0f7a2101f386901c41f', '638ff0f7a2101f386901c42e', '638ff0f7a2101f386901c43a', '638ff0f7a2101f386901c453', '638ff0f7a2101f386901c459', '638ff0f7a2101f386901c460', '638ff0f7a2101f386901c593', '638ff0f7a2101f386901c622', '638ff0f7a2101f386901c721', '65e4897b38c1d6fc2b066c73']
# ----------------------------------------
# Parent Circle ID: 638ff0f4a2101f386901bf2a
# ...

# %%
# Assuming 'data' contains the response from the API
# Let's focus on filtering and displaying parent circles and their sub-circles.

# Create an empty dictionary to store parent circles and their sub-circles
parent_circles_and_subcircles = {}

# Loop through each circle in the data
for circle in data['data']:
    # Get the parent circle ID
    parent_circle = circle.get('parentCircle', None)

    # Get the current circle ID
    current_circle_id = circle.get('id', None)

    # Get the list of subRoles (sub-circles)
    sub_roles = circle.get('subRoles', [])

    # If the circle has a parent, we'll consider it a parent circle
    if parent_circle:
        if parent_circle not in parent_circles_and_subcircles:
            # Add the parent circle to the dictionary if not already added
            parent_circles_and_subcircles[parent_circle] = []

        # Add the current circle as a sub-circle to its parent
        parent_circles_and_subcircles[parent_circle].append(current_circle_id)

# Now print the parent circles and their sub-circles
for parent_circle, sub_circles in parent_circles_and_subcircles.items():
    print(f"Parent Circle ID: {parent_circle}")
    print(f"Sub-Circles: {sub_circles}")
    print("-" * 40)
# Out:
# Parent Circle ID: 638ff0f6a2101f386901c014
# Sub-Circles: ['638ff0f6a2101f386901c0ea', '656341d037d713f77b0ff843', '638ff0f6a2101f386901c034', '638ff0f6a2101f386901c052']
# ----------------------------------------
# Parent Circle ID: 638ff0f4a2101f386901bf2a
# Sub-Circles: ['638ff0f6a2101f386901bf4d', '638ff0f6a2101f386901bfb3', '638ff0f6a2101f386901c154', '638ff0f6a2101f386901c014', '638ff0f6a2101f386901c06e', '638ff0f6a2101f386901c10f', '638ff0f6a2101f386901bff5']
# ----------------------------------------
# Parent Circle ID: 638ff0f6a2101f386901bf4d
# Sub-Circles: ['66e020263cffacf97d09a48e', '638ff0f6a2101f386901bf6f', '656f019a26b427d0770ee59c', '638ff0f6a2101f386901bf8f']
# ----------------------------------------
# Parent Circle ID: 638ff0f6a2101f386901bfb3
# Sub-Circles: ['659e5cc6c375d6022b0582dd']
# ----------------------------------------
# Parent Circle ID: 638ff0f6a2101f386901c06e
# ...

# %%
# Create a dictionary to map circle IDs to their names
circle_id_to_name = {circle['id']: circle['name'] for circle in data['data']}

# Create a dictionary to store circles, their parent circle name, and their associated roles
circle_roles_with_parents = {}

# Loop through each circle in the data
for circle in data['data']:
    # Get the circle ID, name, and parent circle ID
    circle_id = circle.get('id', None)
    circle_name = circle.get('name', "Unknown Circle")
    parent_circle_id = circle.get('parentCircle', None)

    # Get the parent circle name using the ID
    parent_circle_name = circle_id_to_name.get(parent_circle_id, "No Parent Circle")

    # Get the list of core roles and sub roles
    core_roles = circle.get('coreRoles', [])
    sub_roles = circle.get('subRoles', [])

    # Combine core roles and sub roles into a single list of roles within the circle
    all_roles = core_roles + sub_roles

    # Store the roles along with the parent circle name for the current circle
    circle_roles_with_parents[circle_name] = {
        'circle_id': circle_id,
        'parent_circle_name': parent_circle_name,
        'roles': all_roles
    }

# Print each circle with its parent, roles, and ID
for circle_name, info in circle_roles_with_parents.items():
    print(f"Circle Name: {circle_name}")
#    print(f"Circle ID: {info['circle_id']}")
    print(f"Parent Circle Name: {info['parent_circle_name']}")
    print(f"Roles: {info['roles']}")
    print("-" * 40)
# Out:
# Circle Name: Asset Management
# Parent Circle Name: Delivery
# Roles: ['638ff0f6a2101f386901c0ec', '638ff0f6a2101f386901c0f5', '638ff0f6a2101f386901c0fa', '638ff0f7a2101f386901c3f8', '638ff0f7a2101f386901c3ff', '638ff0f7a2101f386901c406', '638ff0f7a2101f386901c416', '638ff0f7a2101f386901c41f', '638ff0f7a2101f386901c42e', '638ff0f7a2101f386901c43a', '638ff0f7a2101f386901c453', '638ff0f7a2101f386901c459', '638ff0f7a2101f386901c460', '638ff0f7a2101f386901c593', '638ff0f7a2101f386901c622', '638ff0f7a2101f386901c721', '65e4897b38c1d6fc2b066c73']
# ----------------------------------------
# Circle Name: Batteries
# Parent Circle Name: Solar and Batteries
# ...

# %%
# Create a dictionary to map role IDs to their names
role_id_to_name = {role['id']: role['name'] for role in data['linked']['roles']}

# Create a dictionary to map circle IDs to their names
circle_id_to_name = {circle['id']: circle['name'] for circle in data['data']}

# Create a dictionary to store circles, their parent circle name, and their associated roles
circle_roles_with_parents = {}

# Loop through each circle in the data
for circle in data['data']:
    # Get the circle ID, name, and parent circle ID
    circle_id = circle.get('id', None)
    circle_name = circle.get('name', "Unknown Circle")
    parent_circle_id = circle.get('parentCircle', None)

    # Get the parent circle name using the ID
    parent_circle_name = circle_id_to_name.get(parent_circle_id, "No Parent Circle")

    # Get the list of core roles and sub roles
    core_roles = circle.get('coreRoles', [])
    sub_roles = circle.get('subRoles', [])

    # Combine core roles and sub roles into a single list of roles within the circle
    all_role_ids = core_roles + sub_roles

    # Map role IDs to their corresponding role names
    all_role_names = [role_id_to_name.get(role_id, "Unknown Role") for role_id in all_role_ids]

    # Store the roles along with the parent circle name for the current circle
    circle_roles_with_parents[circle_name] = {
        'circle_id': circle_id,
        'parent_circle_name': parent_circle_name,
        'roles': all_role_names
    }

# Print each circle with its parent, roles, and ID along with role count
for circle_name, info in circle_roles_with_parents.items():
    print(f"Circle Name: {circle_name}")
#    print(f"Circle ID: {info['circle_id']}")
    print(f"Parent Circle Name: {info['parent_circle_name']}")
    print(f"Number of Roles: {len(info['roles'])}")
    print(f"Roles: {info['roles']}")
    print("-" * 40)
# Out:
# Circle Name: Asset Management
# Parent Circle Name: Delivery
# Number of Roles: 17
# Roles: ['Circle Lead', 'Secretary', 'Facilitator', 'Project Supporter', 'HoTo', 'Technical & Commercial Reporter', 'O&M Process & System Developer', 'Asset Manager', 'Project Integrator', 'Opex Strategist', 'PSG Member', 'Customer Interacter', 'Warranty manager', 'Electrical Senior Authorized Person', 'Financial Control', 'HS(E) specialist for operations', 'Digitalization supporter']
# ----------------------------------------
# Circle Name: Batteries
# Parent Circle Name: Solar and Batteries
# Number of Roles: 26
# ...

# %%
# Create a dictionary to map role IDs to their accountabilities and assigned members
role_id_to_accountabilities = {role['id']: role.get('purpose', 'No Accountability Provided') for role in data['linked']['roles']}
role_id_to_assigned_members = {role['id']: role.get('members', ['No Assigned Members']) for role in data['linked']['roles']}

# Iterate through each circle and its roles
for circle_name, info in circle_roles_with_parents.items():
    print(f"Circle Name: {circle_name}")
    print(f"Circle ID: {info['circle_id']}")
    print(f"Parent Circle Name: {info['parent_circle_name']}")

    # Iterate through roles in the circle
    for role_name in info['roles']:
        # Find the role ID by its name
        role_id = next((role['id'] for role in data['linked']['roles'] if role['name'] == role_name), None)

        # Get accountabilities and assigned members if role_id is found
        if role_id:
            accountabilities = role_id_to_accountabilities.get(role_id, 'No Accountability Provided')
            assigned_members = role_id_to_assigned_members.get(role_id, ['No Assigned Members'])

            # Safely retrieve member names by checking if the item is a dictionary
            member_names = [
                member.get('name', 'Unknown Member') if isinstance(member, dict) else member
                for member in assigned_members
            ]
        else:
            accountabilities = 'No Accountability Found'
            member_names = ['No Assigned Members']

        print(f"Role: {role_name}")
        print(f"Accountabilities: {accountabilities}")
        print(f"Assigned Members: {', '.join(member_names)}")
        print("-" * 40)

    print("=" * 60)
# Out:
# Circle Name: Asset Management
# Circle ID: 638ff0f6a2101f386901c0ea
# Parent Circle Name: Delivery
# Role: Circle Lead
# Accountabilities: The Circle Lead holds the Purpose of the overall Circle.
# Assigned Members: No Assigned Members
# ----------------------------------------
# Role: Secretary
# Accountabilities: Steward the Circle’s governance records and stabilize its record-keeping process.
# Assigned Members: No Assigned Members
# ----------------------------------------
# Role: Facilitator
# Accountabilities: Circle governance and operational practices aligned with the Constitution.
# Assigned Members: No Assigned Members
# ----------------------------------------
# Role: Project Supporter
# Accountabilities: Operation ready projects @ FID and handover
# Assigned Members: No Assigned Members
# ----------------------------------------
# Role: HoTo
# Accountabilities: Defined Hand-over Take-Over and quality standards
# Assigned Members: No Assigned Members
# ...

# %%
import requests
import pandas as pd



# API endpoint to get roles in the organization
api_url = f'https://app.holaspirit.com/api/organizations/{organization_id}/roles'

# Headers for the GET request
headers = {
    'Authorization': f'Bearer {api_token}',
    'Accept': 'application/json'
}

# Send the GET request
response = requests.get(api_url, headers=headers)

# Check if the request was successful
if response.status_code == 200:
    print("Data successfully retrieved!")

    # Print the raw response to inspect its structure
    data = response.json()
    print(data)  # Inspect this part to understand the structure

    # Assuming the roles are inside a dictionary, e.g., {'data': [...]}
    roles_list = data.get('data', data)  # Adjust 'data' to the correct key if needed

    # Process and consolidate the data with respect to role_id
    roles = []
    for role in roles_list:
        roles.append({
            'role_id': role['id'],
            'name': role['name'],
            'purpose': role.get('purpose', ''),
            'assignedMembers': role.get('assignedMembers', []),
            'domains': role.get('domains', []),
            'accountabilities': role.get('accountabilities', [])
        })

    # Convert the roles data into a pandas DataFrame for easier handling
    df = pd.DataFrame(roles)

    # Display the DataFrame in Colab
    from IPython.display import display
    display(df)

else:
    print(f"Failed to access the API. Status code: {response.status_code}")
    print("Error message:", response.text)
# Out:
# Data successfully retrieved!
# ...

# %%
import requests
from bs4 import BeautifulSoup

# Function to get role details from the API
def get_role_details(organization_id, role_id, api_token):
    api_url = f'https://app.holaspirit.com/api/organizations/{organization_id}/roles/{role_id}'

    headers = {
        'Authorization': f'Bearer {api_token}',
        'Accept': 'application/json'
    }

    response = requests.get(api_url, headers=headers)

    if response.status_code == 200:
        return response.json()  # Return the data in JSON format
    else:
        print(f"Failed to retrieve role data: {response.status_code}")
        return None

# Function to clean HTML tags
def clean_html(raw_html):
    return BeautifulSoup(raw_html, "html.parser").text

# Function to process role data and display it
def display_role_info(role_data):
    # Extract basic details
    role_name = role_data['data'].get('name', 'Unknown')
    purpose_html = role_data['data'].get('purpose', 'No purpose provided')
    purpose = clean_html(purpose_html)  # Clean the HTML tags from the purpose

    # Extract accountabilities (as descriptions)
    accountabilities = []
    for accountability in role_data['data'].get('accountabilities', []):
        # Check if accountability is a string or a dictionary
        if isinstance(accountability, dict):
            accountability_desc = accountability.get('description', 'No accountability description')
        else:
            accountability_desc = accountability  # If it's a string, use it as-is
        accountabilities.append(clean_html(accountability_desc))

    # Extract assigned members' names from the linked section
    assigned_members_ids = role_data['data'].get('assignedMembers', [])
    assigned_members = [
        member['displayName'] for member in role_data['linked']['members']
        if member['id'] in assigned_members_ids
    ]

    # Display the details
    print(f"Role Name: {role_name}")
    print(f"Purpose: {purpose}")
    print(f"Accountabilities: {', '.join(accountabilities) if accountabilities else 'No accountabilities provided'}")
    print(f"Assigned Members: {', '.join(assigned_members) if assigned_members else 'No assigned members'}")
    print("-" * 40)

# Example usage
organization_id = "638ff0f4a2101f386901bf22"  # Replace with your organization ID
role_id = "63ee25fb6ba3c5cae20a98dd"         # Replace with the specific role ID
api_token = "   "            # Replace with your actual API token

# Fetch role details
role_data = get_role_details(organization_id, role_id, api_token)

# Display role information if data is successfully fetched
if role_data:
    display_role_info(role_data)
# Out:
# Role Name: MT Solar Development: Representative Germany
# Purpose: Bring Germany specific knowledge into MT Solar Development
# Accountabilities: 63ee25fb6ba3c5cae20a98df, 63ee25fb6ba3c5cae20a98e0, 63ee25fb6ba3c5cae20a98e1, 63ee25fb6ba3c5cae20a98e2
# Assigned Members: No assigned members
# ----------------------------------------

# %%
import requests

# Function to fetch role details from the API
def get_role_details(organization_id, role_id, api_token):
    # Define the API URL
    api_url = f'https://app.holaspirit.com/api/organizations/{organization_id}/roles/{role_id}'

    # Set the headers, including the API token for authorization
    headers = {
        'Authorization': f'Bearer {api_token}',
        'Accept': 'application/json'
    }

    # Send the GET request
    response = requests.get(api_url, headers=headers)

    # Check if the request was successful
    if response.status_code == 200:
        return response.json()  # Return the JSON data if successful
    else:
        print(f"Failed to retrieve role data: {response.status_code}")
        return None

# Example usage
organization_id = "638ff0f4a2101f386901bf22"  # Replace with your organization ID
role_id = "63ee25fb6ba3c5cae20a98dd"         # Replace with the specific role ID
           # Replace with your actual API token

# Fetch role details
role_data = get_role_details(organization_id, role_id, api_token)

# Print role data if successfully retrieved

role_data
# Out:
# {'data': {'policies': [],
#   'parentCircle': '63ed3640ccc3e84b57036aa5',
#   'timeSpent': {'totalMemberCount': 1,
#    'FTEFilledMemberCount': 0,
#    'FTEValue': 0},
#   'visibleSubRoles': [],
#   'visibleSubMembers': [],
#   'template': None,
#   'isTransversalRole': False,
#   'transversalRoleTargets': [],
#   'transversalRoleDomains': None,
#   'transversalRoleAccountabilities': None,
#   'transversalRoleMembers': None,
#   'transversalRolePolicies': None,
#   'organization': '638ff0f4a2101f386901bf22',
#   'id': '63ee25fb6ba3c5cae20a98dd',
#   'name': 'MT Solar Development: Representative Germany',
#   'circle': None,
#   'purpose': '<p>Bring Germany specific knowledge into MT Solar Development</p>',
#   'assignedMembers': ['64ede766e8fd2473a8003459'],
#   'hasAssignation': True,
#   'domains': [],
#   'accountabilities': ['63ee25fb6ba3c5cae20a98df',
#    '63ee25fb6ba3c5cae20a98e0',
#    '63ee25fb6ba3c5cae20a98e1',
#    '63ee25fb6ba3c5cae20a98e2'],
#   'effortNeeded': None,
# ...

# %%
member_name = role_data['linked']['members'][0]['displayName']
print(member_name)

# Fetch accountability descriptions from the 'linked' section
accountability_descriptions = [
    accountability.get('description', 'No description available')
    for accountability in role_data['linked']['accountabilities']
]
print(accountability_descriptions)
# Out:
# Margit Deimel
# ['<p>Keeping MT updated with Germany specific knowledge, being relevant for MT Steering</p>', '<p>Sharing and learning from best practices between solar development markets</p>', '<p>Together with LeadLink Solar Development discuss on Business related topics</p>', "<p>Helping LeadLink with monitoring Development OKR's and KPI's</p>"]

# %% [markdown]
# This code get all the circles, then get all roles within the circles and then get role infos of all roles. In this way, Assigned Members and their Accountabilities are refreshed

# %%
import requests

# Function to get all circles from the organization
def get_all_circles(organization_id, api_token):
    api_url = f'https://app.holaspirit.com/api/organizations/{organization_id}/circles'
    headers = {
        'Authorization': f'Bearer {api_token}',
        'Accept': 'application/json'
    }

    response = requests.get(api_url, headers=headers)

    if response.status_code == 200:
        return response.json()  # Return the JSON data
    else:
        print(f"Failed to retrieve circles: {response.status_code}")
        return None

# Function to get all roles in a specific circle
def get_roles_in_circle(organization_id, circle_id, api_token):
    api_url = f'https://app.holaspirit.com/api/organizations/{organization_id}/roles-custom-fields?circle={circle_id}'
    headers = {
        'Authorization': f'Bearer {api_token}',
        'Accept': 'application/json'
    }

    response = requests.get(api_url, headers=headers)

    if response.status_code == 200:
        return response.json()  # Return the JSON data
    else:
        print(f"Failed to retrieve roles for circle {circle_id}: {response.status_code}")
        return None

# Function to get role details
def get_role_details(organization_id, role_id, api_token):
    api_url = f'https://app.holaspirit.com/api/organizations/{organization_id}/roles/{role_id}'
    headers = {
        'Authorization': f'Bearer {api_token}',
        'Accept': 'application/json'
    }

    response = requests.get(api_url, headers=headers)

    if response.status_code == 200:
        return response.json()  # Return the JSON data
    else:
        print(f"Failed to retrieve role data for {role_id}: {response.status_code}")
        return None

# Function to display role member names and accountabilities
def display_role_info(role_data):
    # Check if the role has assigned members
    if 'linked' in role_data and 'members' in role_data['linked']:
        # Fetch all assigned member names (in case there are multiple members)
        member_names = [member.get('displayName', 'No Member Assigned') for member in role_data['linked']['members']]
    else:
        member_names = ['No Member Assigned']

    # Fetch accountability descriptions from the 'linked' section
    accountability_descriptions = [
        accountability.get('description', 'No description available')
        for accountability in role_data['linked'].get('accountabilities', [])
    ]

    # Print members and accountabilities
    print(f"Assigned Members: {', '.join(member_names)}")
    print(f"Accountabilities: {', '.join(accountability_descriptions) if accountability_descriptions else 'No Accountabilities'}")
    print("-" * 40)


# Main function to retrieve and process all circles and roles
def process_circles_and_roles(organization_id, api_token):
    # Step 1: Get all circles in the organization
    circles_data = get_all_circles(organization_id, api_token)

    if circles_data:
        # Step 2: For each circle, get roles and process them
        all_circles = circles_data.get('data', [])

        for circle in all_circles:
            circle_id = circle.get('id')
            circle_name = circle.get('name', 'Unknown Circle')

            print(f"Processing Circle: {circle_name}")

            # Step 3: Get all roles in the circle
            roles_data = get_roles_in_circle(organization_id, circle_id, api_token)

            if roles_data:
                all_roles = roles_data.get('data', [])

                for role in all_roles:
                    role_id = role.get('id')
                    role_name = role.get('name', 'Unknown Role')

                    print(f"Processing Role: {role_name}")
                    print(f"Processing Circle: {circle_name}")

                    # Step 4: For each role, get role details
                    role_data = get_role_details(organization_id, role_id, api_token)

                    if role_data:
                        # Step 5: Display member names and accountabilities
                        display_role_info(role_data)

# Example usage
organization_id = "638ff0f4a2101f386901bf22"  # Replace with your organization ID
api_token = "api:NTc4NGZjMzFkMjNhODNmMmYxNzExNDhlNzFiZmY2OWMyYTFkYTFhYzlmZTBmZTIzZWRmOTM2OGQ5YzVhMmNkMQ"              # Replace with your API token

process_circles_and_roles(organization_id, api_token)
# Out:
# Processing Circle: Asset Management
# Processing Role: Asset Manager
# Processing Circle: Asset Management
# Assigned Members: Jaco Hovius, Ahmed Altarawneh, Siddharth Dutta, Srinivas Krishna, Maaike Hermse
# ...

# %%
import requests

# Function to fetch role relations from the API
def get_role_relations(organization_id, api_token):
    relations_url = f'https://app.holaspirit.com/api/organizations/{organization_id}/roles/relations'
    headers = {
        'Authorization': f'Bearer {api_token}',
        'Accept': 'application/json'
    }
    response = requests.get(relations_url, headers=headers)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to retrieve role relations: {response.status_code}")
        return None


organization_id = "638ff0f4a2101f386901bf22"  # Replace with your organization ID
api_token = "   "

role_relations_data = get_role_relations(organization_id, api_token)


# Function to get role information by role_id
def get_role_info(organization_id, role_id, api_token):
    role_url = f'https://app.holaspirit.com/api/organizations/{organization_id}/roles/{role_id}'
    headers = {
        'Authorization': f'Bearer {api_token}',
        'Accept': 'application/json'
    }
    response = requests.get(role_url, headers=headers)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to retrieve role info for role_id {role_id}: {response.status_code}")
        return None
# Function to display role relationships with names
def display_role_relationships_with_names(organization_id, relations_data, api_token):
    for relation in relations_data['data']:
        origin_role_id = relation['origin']
        target_role_id = relation['target']

        # Fetch role names using the role info API
        origin_role_data = get_role_info(organization_id, origin_role_id, api_token)
        target_role_data = get_role_info(organization_id, target_role_id, api_token)

        # Get role names
        origin_role_name = origin_role_data['data'].get('name', 'Unknown Role') if origin_role_data else 'Unknown Role'
        target_role_name = target_role_data['data'].get('name', 'Unknown Role') if target_role_data else 'Unknown Role'

        print(f"Role {origin_role_name} is related to Role {target_role_name}")

# Call the function with role relations and display the results
if role_relations_data:
    display_role_relationships_with_names(organization_id, role_relations_data, api_token)
else:
    print("No role relations found.")
# Out:
# Role Cross Link to @Operations is related to Role Batteries
# Role Cross Link to @Operations is related to Role Asset Management
# Role Technology Interface is related to Role Battery Engineering
# Role Technology Interface is related to Role Battery-Engineering Book Keeper
# Role Circle Lead is related to Role Batteries
# Role Delivery is related to Role Solar Development
# Role Engineering is related to Role Solar Development
# Role Engineering is related to Role Delivery Construction
# Role Engineering is related to Role Asset Management
# Role Asset Management is related to Role Transactions & Customers
# Role Project Sponsor is related to Role Batteries
# Role Project Sponsor is related to Role Battery Package Manager
# Role Project Sponsor is related to Role Project Manager
# Role First-Level-Support is related to Role Batteries
# Role First-Level-Support is related to Role Market analytics & model-based optimization
# Role Business Partner is related to Role Project Sponsor
# ...

# %%
import requests

# Function to get role relations
def get_role_relations(organization_id, api_token):
    relations_url = f'https://app.holaspirit.com/api/organizations/{organization_id}/roles/relations'
    headers = {
        'Authorization': f'Bearer {api_token}',
        'Accept': 'application/json'
    }
    response = requests.get(relations_url, headers=headers)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to retrieve role relations: {response.status_code}")
        return None

# Function to get role info
def get_role_info(organization_id, role_id, api_token):
    role_url = f'https://app.holaspirit.com/api/organizations/{organization_id}/roles/{role_id}'
    headers = {
        'Authorization': f'Bearer {api_token}',
        'Accept': 'application/json'
    }
    response = requests.get(role_url, headers=headers)

    if response.status_code == 200:
        return response.json()
    else:
        print(f"Failed to retrieve role info for role_id {role_id}: {response.status_code}")
        return None

# Function to get circle name using circle ID
def get_circle_name(organization_id, circle_id, api_token):
    circle_url = f'https://app.holaspirit.com/api/organizations/{organization_id}/circles/{circle_id}'
    headers = {
        'Authorization': f'Bearer {api_token}',
        'Accept': 'application/json'
    }
    response = requests.get(circle_url, headers=headers)

    if response.status_code == 200:
        circle_data = response.json()
        return circle_data['data'].get('name', 'Unknown Circle')
    else:
        print(f"Failed to retrieve circle info for circle_id {circle_id}: {response.status_code}")
        return 'Unknown Circle'

# Function to display role relationships with role names and circle names
def display_role_relationships_with_names_and_circles(organization_id, relations_data, api_token):
    for relation in relations_data['data']:
        origin_role_id = relation['origin']
        target_role_id = relation['target']

        # Fetch role names and circle info using the role info API
        origin_role_data = get_role_info(organization_id, origin_role_id, api_token)
        target_role_data = get_role_info(organization_id, target_role_id, api_token)

        # Get role names and circle IDs
        origin_role_name = origin_role_data['data'].get('name', 'Unknown Role') if origin_role_data else 'Unknown Role'
        target_role_name = target_role_data['data'].get('name', 'Unknown Role') if target_role_data else 'Unknown Role'

        # Fetch the circle name using the circle ID
        origin_circle_id = origin_role_data['data'].get('circle', None) if origin_role_data else None
        target_circle_id = target_role_data['data'].get('circle', None) if target_role_data else None

        origin_circle_name = get_circle_name(organization_id, origin_circle_id, api_token) if origin_circle_id else 'No Circle'
        target_circle_name = get_circle_name(organization_id, target_circle_id, api_token) if target_circle_id else 'No Circle'

        # Display the relation with role names and circle names
        print(f"Role {origin_role_name} (Circle: {origin_circle_name}) is related to Role {target_role_name} (Circle: {target_circle_name})")

# Example usage
organization_id = "638ff0f4a2101f386901bf22"  # Replace with your organization ID
api_token = "   "  # Replace with your actual API token

# Step 1: Fetch role relations
role_relations_data = get_role_relations(organization_id, api_token)

# Step 2: Display role relationships with role names and circles
if role_relations_data:
    display_role_relationships_with_names_and_circles(organization_id, role_relations_data, api_token)
else:
    print("No role relations found.")
# Out:
# Role Cross Link to @Operations (Circle: No Circle) is related to Role Batteries (Circle: Batteries)
# Role Cross Link to @Operations (Circle: No Circle) is related to Role Asset Management (Circle: Asset Management)
# Role Technology Interface (Circle: No Circle) is related to Role Battery Engineering (Circle: Battery Engineering)
# Role Technology Interface (Circle: No Circle) is related to Role Battery-Engineering Book Keeper (Circle: No Circle)
# Role Circle Lead (Circle: No Circle) is related to Role Batteries (Circle: Batteries)
# Role Delivery (Circle: Delivery) is related to Role Solar Development (Circle: Solar Development)
# Role Engineering (Circle: Engineering) is related to Role Solar Development (Circle: Solar Development)
# Role Engineering (Circle: Engineering) is related to Role Delivery Construction (Circle: Delivery Construction)
# Role Engineering (Circle: Engineering) is related to Role Asset Management (Circle: Asset Management)
# ...
